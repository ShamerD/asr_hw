# %%
# !git clone -b one-batch-overfit https://github.com/ShamerD/asr_hw.git
# Out:
# Cloning into 'asr_hw'...
# remote: Enumerating objects: 283, done.
# remote: Counting objects: 100% (283/283), done.
# remote: Compressing objects: 100% (179/179), done.
# remote: Total 283 (delta 148), reused 231 (delta 98), pack-reused 0
# Receiving objects: 100% (283/283), 778.56 KiB | 7.14 MiB/s, done.
# Resolving deltas: 100% (148/148), done.

# %%
# !rm -r asr_hw

# %%
# %pip install -r asr_hw/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 287 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 393 kB 42.2 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 40.3 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 37.2 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 48.4 MB/s
# ...
#      |████████████████████████████████| 56 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 831.4 MB 6.8 kB/s
# ...
#      |████████████████████████████████| 22.1 MB 47.0 MB/s
# ...
#      |████████████████████████████████| 125 kB 46.2 MB/s
# ...
#      |████████████████████████████████| 243 kB 46.0 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 28.1 MB/s
# ...
#      |████████████████████████████████| 58 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 97 kB 6.2 MB/s
# ...
#      |████████████████████████████████| 139 kB 42.2 MB/s
# ...
#      |████████████████████████████████| 180 kB 48.8 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.8 MB/s
# ...
#      |████████████████████████████████| 160 kB 36.6 MB/s
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !python asr_hw/train.py -c asr_hw/hw_asr/config.json
# Out:
# Loading part dev-clean
# ...
# dev-clean.tar.gz: 338MB [00:14, 24.0MB/s]
# Preparing librispeech folders: dev-clean: 100% 97/97 [00:00<00:00, 117.50it/s]
# 61 (2.3%) records are longer then 20.0 seconds. Excluding them.
# 288 (10.7%) records are longer then 200 characters. Excluding them.
# Filtered 288(10.7%) records  from dataset
# BaselineLSTM(
#   (lstm): LSTM(128, 256, num_layers=3, batch_first=True)
#   (fc): Linear(in_features=256, out_features=28, bias=True)
# )
# Trainable parameters: 1455132
# wandb: Currently logged in as: shamerd (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.12.4
# wandb: Syncing run devout-oath-10
# wandb: ⭐️ View project at https://wandb.ai/shamerd/asr_project
# wandb: 🚀 View run at https://wandb.ai/shamerd/asr_project/runs/2drdnjd2
# wandb: Run data is saved locally in /content/wandb/run-20211014_222647-2drdnjd2
# wandb: Run `wandb offline` to turn off syncing.
#
# ...
