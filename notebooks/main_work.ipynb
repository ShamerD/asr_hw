# %% [markdown]
# ## Preparation

# %%
# %cd ..
# Out:
# /home/jupyter/work/resources/asr_hw

# %%
# %pwd
# Out:
# '/home/jupyter/work/resources/asr_hw'

# %%
# %pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 285 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 290 kB 53.1 MB/s
# ...
#      |████████████████████████████████| 393 kB 35.4 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 47.7 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 40.2 MB/s
# ...
#      |████████████████████████████████| 56 kB 6.0 MB/s
# ...
#      |████████████████████████████████| 831.4 MB 2.0 kB/s
# ...
#      |████████████████████████████████| 112 kB 96.8 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 58.5 MB/s
# ...
#      |████████████████████████████████| 76 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 287 kB 70.9 MB/s
# ...
#      |████████████████████████████████| 287 kB 89.2 MB/s
# ...
#      |████████████████████████████████| 287 kB 1.1 kB/s
# ...
#      |████████████████████████████████| 285 kB 9.2 kB/s
# ...
#      |████████████████████████████████| 270 kB 87.9 MB/s
# ...

# %%
# !cd .. && git clone --recursive https://github.com/parlance/ctcdecode.git
# Out:
# Cloning into 'ctcdecode'...
# remote: Enumerating objects: 1102, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 1102 (delta 16), reused 28 (delta 13), pack-reused 1063
# Receiving objects: 100% (1102/1102), 780.91 KiB | 4.15 MiB/s, done.
# Resolving deltas: 100% (529/529), done.
# Submodule 'third_party/ThreadPool' (https://github.com/progschj/ThreadPool.git) registered for path 'third_party/ThreadPool'
# Submodule 'third_party/kenlm' (https://github.com/kpu/kenlm.git) registered for path 'third_party/kenlm'
# Cloning into '/home/jupyter/work/resources/ctcdecode/third_party/ThreadPool'...
# remote: Enumerating objects: 82, done.
# remote: Total 82 (delta 0), reused 0 (delta 0), pack-reused 82
# Cloning into '/home/jupyter/work/resources/ctcdecode/third_party/kenlm'...
# remote: Enumerating objects: 14047, done.
# remote: Counting objects: 100% (360/360), done.
# ...

# %%
# %pip install ../../ctcdecode/
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Processing /home/jupyter/work/resources/ctcdecode
# ...
#   Created wheel for ctcdecode: filename=ctcdecode-1.0.3-cp37-cp37m-linux_x86_64.whl size=13245373 sha256=6b281a5158b07cfe6c50b4f02d4bdc8fbe10b8d1dd0571cb739d2a050dbdee0f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-em5wonv8/wheels/57/6e/d5/ce5821cfcb9e30b8afd9483a1019c01ad281f3faf79df117a2
# Successfully built ctcdecode
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.

# %%
import wandb
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: shamerd (use `wandb login --relogin` to force relogin)
# True

# %% [markdown]
# ## Train

# %%
#!g1.1
# !python3 train.py -c hw_asr/configs/quartznet_main.json
# Out:
# lidation:  39%|████████████▏                  | 30/76 [03:04<04:43,  6.16s/it]ng W&B API: rpc error: code = ResourceExhausted desc = Quota exceeded for quota metric 'Generate credentials request' and limit 'Generate credentials request per minute' of service 'iamcredentials.googleapis.com' for consumer 'project_number:959666683579'. (<Response [500]>)
# wandb: ERROR Error while calling W&B API: rpc error: code = ResourceExhausted desc = Quota exceeded for quota metric 'Generate credentials request' and limit 'Generate credentials request per minute' of service 'iamcredentials.googleapis.com' for consumer 'project_number:959666683579'. (<Response [500]>)
# wandb: ERROR Error while calling W&B API: rpc error: code = ResourceExhausted desc = Quota exceeded for quota metric 'Generate credentials request' and limit 'Generate credentials request per minute' of service 'iamcredentials.googleapis.com' for consumer 'project_number:959666683579'. (<Response [500]>)
# ...

# %%
#!g1.1
# !python3 train.py -c hw_asr/configs/quartznet_main_b64.json -r saved/models/quartznet_main/1026_150852.382262/checkpoint-epoch10.pth
# Out:
# wandb: Waiting for W&B process to finish, PID 14376... (success).
# wandb:
# wandb: Run history:
# wandb:                    /epoch ▁
# wandb:        train/CER (argmax) ▇▇▇▇▇▇▇█▇▇██▄▃▂▁▁▁▁▂▂▃▃▄▄▄▅▄▅▅▅▅▅▅▅▅▅▅▅▅
# wandb:        train/WER (argmax) ▅▅▄▅▅▆▆▇▇▇██▄▃▂▁▁▁▂▄▃▄▅▅▆▅▅▅▅▅▅▄▄▄▅▄▅▅▅▅
# wandb:           train/grad norm ▁▁▁▁▁▂▂▂▂▂▂▃▆███████▇▇▇▇▇▆▆▆▅▅▄▄▃▃▂▂▂▁▁▁
# wandb:       train/learning rate ▁▁▂▃▄▅▆▇█████████▇▇▇▇▇▆▆▆▆▅▅▅▄▄▄▄▃▃▃▂▂▂▂
# wandb:                train/loss ███████████▇▅▄▄▄▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:       train/steps_per_sec ▇▇▃▇█▆▇▃▇▅▆▆▇▆▇▆▇▅▇▆▅▆▄▇▅▅▆▁▆▄▅▄▄▄▅▅▅▄▄▅
# wandb:        valid/CER (argmax) ▅▅▅▅▅▅▅▅▆▆█▇▄▂▁▁▁▁▁▁▁▁▂▁▁▃▂▁▁▁▂▁▂▁▂▁▂▂▁▁
# wandb:   valid/CER (beam search) ███████████▆▅▄▂▃▃▁▂▃▂▂▂▃▃▃▃▄▂▃▃▃▃▃▄▂▄▃▁▃
# wandb:        valid/WER (argmax) ▅▅▅▅▅▅▅▅▆▆█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:   valid/WER (beam search) ▆▆▆▆▆▆▅▆▆▆█▄▄▃▂▂▁▁▁▂▂▁▂▂▂▂▂▂▁▂▂▂▂▂▂▁▂▂▁▁
# wandb:               valid/epoch ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# ...

# %%
#!g1.1
wandb.finish(0)

# %%
#!g1.1
# !python3 train.py -c hw_asr/configs/quartznet_main_360.json -r saved/models/quartznet_main/1026_192642.019336/checkpoint-epoch50.pth
# Out:
# ^C
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-11-fbd486f10a1a> in <module>
# ----> 1 get_ipython().system('python3 train.py -c hw_asr/configs/quartznet_main_360.json -r saved/models/quartznet_main/1026_192642.019336/checkpoint-epoch50.pth')
#       2 #
#
# /kernel/lib/python3.7/site-packages/ml_kernel/kernel.py in <lambda>(code)
#     261
#     262         self._script_executor = ScriptExecutor(ProcessHandler().system)
# --> 263         self.shell.system = lambda code: self._script_executor.execute("bash", code)
#     264
#     265     def _init_message_handlers(self):
#
# /kernel/lib/python3.7/site-packages/ml_kernel/script_executor.py in execute(self, lang, code)
#      33         return_code = self._system(code)
#      34         if return_code != 0:
# ---> 35             raise Exception('Process exited with code %d' % return_code)
#
# ...

# %%
#!g1.1
# !wget -q -O ./lm.arpa.gz http://www.openslr.org/resources/11/3-gram.pruned.1e-7.arpa.gz
# !gunzip ./lm.arpa.gz

# %%
#!g1.1
# !python3 train.py -c hw_asr/configs/quartznet_main_augs.json -r saved/models/quartznet_main/1027_110901.083316/checkpoint-epoch60.pth
# Out:
# 17 (0.0%) records are longer then 20.0 seconds. Excluding them.
# 456 (0.4%) records are longer then 300 characters. Excluding them.
# Filtered 458(0.4%) records  from dataset
# 61 (2.3%) records are longer then 20.0 seconds. Excluding them.
# 292 (10.8%) records are longer then 200 characters. Excluding them.
# Filtered 292(10.8%) records  from dataset
# QuartzNet(
#   (c1): TCSConv(
#     (net): Sequential(
#       (0): Conv1d(128, 256, kernel_size=(33,), stride=(2,), padding=(16,), groups=128)
#       (1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU()
#     )
#   )
#   (blocks): Sequential(
#     (0): QuartzNetBlock(
#       (net): Sequential(
#         (0): TCSConv(
#           (net): Sequential(
#             (0): Conv1d(256, 256, kernel_size=(33,), stride=(1,), padding=(16,), groups=256)
#             (1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
# ...

# %%
#!g1.1
wandb.finish(1)

# %%
#!g1.1
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=14tFL0ylwPHDFWZDqlELCsSKl-U_ze6cC' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=14tFL0ylwPHDFWZDqlELCsSKl-U_ze6cC" -O default_test/checkpoint.pth && rm -rf /tmp/cookies.txt
# Out:
# --2021-10-27 20:53:03--  https://docs.google.com/uc?export=download&confirm=dwY3&id=14tFL0ylwPHDFWZDqlELCsSKl-U_ze6cC
# Resolving docs.google.com (docs.google.com)... 173.194.222.194, 2a00:1450:4010:c0b::c2
# Connecting to docs.google.com (docs.google.com)|173.194.222.194|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0s-8o-docs.googleusercontent.com/docs/securesc/kkej8f6c3qidfpdod1tqrbfpv37fkhj8/quti8uitgv8opnr41qsgtl7kesb739kl/1635367950000/03265012831958327717/14236934267203804257Z/14tFL0ylwPHDFWZDqlELCsSKl-U_ze6cC?e=download [following]
# --2021-10-27 20:53:04--  https://doc-0s-8o-docs.googleusercontent.com/docs/securesc/kkej8f6c3qidfpdod1tqrbfpv37fkhj8/quti8uitgv8opnr41qsgtl7kesb739kl/1635367950000/03265012831958327717/14236934267203804257Z/14tFL0ylwPHDFWZDqlELCsSKl-U_ze6cC?e=download
# Resolving doc-0s-8o-docs.googleusercontent.com (doc-0s-8o-docs.googleusercontent.com)... 173.194.73.132, 2a00:1450:4010:c0f::84
# ...

# %%
#!g1.1
# !python3 ./test.py -c default_test/config.json -r default_test/checkpoint.pth
# Out:
# 17 (0.0%) records are longer then 20.0 seconds. Excluding them.
# 456 (0.4%) records are longer then 300 characters. Excluding them.
# Filtered 458(0.4%) records  from dataset
# 61 (2.3%) records are longer then 20.0 seconds. Excluding them.
# 292 (10.8%) records are longer then 200 characters. Excluding them.
# Filtered 292(10.8%) records  from dataset
# 92 (3.5%) records are longer then 20.0 seconds. Excluding them.
# 334 (12.7%) records are longer then 200 characters. Excluding them.
# Filtered 335(12.8%) records  from dataset
# QuartzNet(
#   (c1): TCSConv(
#     (net): Sequential(
#       (0): Conv1d(128, 256, kernel_size=(33,), stride=(2,), padding=(16,), groups=128)
#       (1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU()
#     )
#   )
#   (blocks): Sequential(
#     (0): QuartzNetBlock(
#       (net): Sequential(
#         (0): TCSConv(
# ...

# %%
#!g1.1
